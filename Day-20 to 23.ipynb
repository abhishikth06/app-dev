# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import numpy as np

# %%
cars = pd.read_csv('Cars.csv')
cars
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
cars.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   MPG     81 non-null     float64
#  2   VOL     81 non-null     int64
#  3   SP      81 non-null     float64
#  4   WT      81 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.3 KB

# %%
cars.isnull().sum()
# Out:
# HP     0
# MPG    0
# VOL    0
# SP     0
# WT     0
# dtype: int64

# %%
cars.shape
# Out:
# (81, 5)

# %%
cars.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %% [markdown]
# ## Correlation Matrix

# %%
cars.corr()
# Out:
#            HP       MPG       VOL        SP        WT
# HP   1.000000 -0.725038  0.077459  0.973848  0.076513
# MPG -0.725038  1.000000 -0.529057 -0.687125 -0.526759
# VOL  0.077459 -0.529057  1.000000  0.102170  0.999203
# SP   0.973848 -0.687125  0.102170  1.000000  0.102439
# WT   0.076513 -0.526759  0.999203  0.102439  1.000000

# %% [markdown]
# ## Exploratory data analysis (EDA)

# %% [raw]
# distplot
# box plot
# scatterplot

# %%
import warnings
warnings.filterwarnings('ignore')
plt.title('Distribution of Weight of vechile in thousand pounds')
plt.xlabel('Weight in Thousand pounds')
sns.distplot(cars['HP'], color ='green')
plt.show()

# %%
sns.distplot(cars['MPG'], color ='blue')
plt.title('Distribution of Miles per Gallon (MPG)')
plt.xlabel('Miles per Gallon (MPG)')
plt.show()

# %%
sns.distplot(cars['VOL'], color ='purple')
# Out:
# <Axes: xlabel='VOL', ylabel='Density'>

# %%
sns.distplot(cars['SP'], color ='black')
# Out:
# <Axes: xlabel='SP', ylabel='Density'>

# %%
sns.distplot(cars['WT'], color ='orange')
# Out:
# <Axes: xlabel='WT', ylabel='Density'>

# %%
sns.boxplot(x=cars['HP'])
plt.show()

# %%
sns.boxplot(x=cars['MPG'])
plt.show()

# %%
sns.boxplot(x=cars['VOL'])
plt.show()

# %%
sns.boxplot(x=cars['SP'])
plt.show()

# %%
sns.boxplot(x=cars['WT'])
plt.show()

# %%
plt.scatter(x=cars['VOL'],y=cars['MPG'])
plt.title('VOL VS MPG')
plt.xlabel('Volume means Size(VOL)')
plt.ylabel('Miles per Gallon (MPG)')
# Out:
# Text(0, 0.5, 'Miles per Gallon (MPG)')

# %%
plt.scatter(x=cars['HP'],y=cars['MPG'])
plt.title('HP VS MPG')
plt.xlabel('HP (Horse Power)')
plt.ylabel('Miles per Gallon (MPG)')
# Out:
# Text(0, 0.5, 'Miles per Gallon (MPG)')

# %%
plt.scatter(x=cars['SP'],y=cars['MPG'])
plt.title('SP VS MPG')
plt.xlabel('SP (Highest Speed)')
plt.ylabel('Miles per Gallon (MPG)')
# Out:
# Text(0, 0.5, 'Miles per Gallon (MPG)')

# %%
plt.scatter(x=cars['WT'],y=cars['MPG'])
plt.title('WT VS MPG')
plt.xlabel('WT (Weight)')
plt.ylabel('Miles per Gallon (MPG)')
# Out:
# Text(0, 0.5, 'Miles per Gallon (MPG)')

# %%
plt.scatter(x=cars['MPG'],y=cars['MPG'])
plt.title('MPG VS MPG')
plt.xlabel('Miles per Gallon (MPG)')
plt.ylabel('Miles per Gallon (MPG)')
# Out:
# Text(0, 0.5, 'Miles per Gallon (MPG)')

# %%
cars.corr()
# Out:
#            HP       MPG       VOL        SP        WT
# HP   1.000000 -0.725038  0.077459  0.973848  0.076513
# MPG -0.725038  1.000000 -0.529057 -0.687125 -0.526759
# VOL  0.077459 -0.529057  1.000000  0.102170  0.999203
# SP   0.973848 -0.687125  0.102170  1.000000  0.102439
# WT   0.076513 -0.526759  0.999203  0.102439  1.000000

# %%
sns.heatmap(cars.corr(),cmap='Blues',annot=True)

# > 0.85 Multi-co-linearity ---> We need to avoid this
#
# Out:
# <Axes: >

# %%
plt.scatter(x=cars['HP'],y=cars['WT'])
plt.title('HP VS WT')
# Out:
# Text(0.5, 1.0, 'HP VS WT')

# %%
plt.scatter(x=cars['HP'],y=cars['VOL'])
plt.title('HP VS VOL')
# Out:
# Text(0.5, 1.0, 'HP VS VOL')

# %%
plt.scatter(x=cars['HP'],y=cars['SP'])
plt.title('HP VS SP')
# Out:
# Text(0.5, 1.0, 'HP VS SP')

# %%
plt.scatter(x=cars['WT'],y=cars['VOL'])
plt.title('Wt VS VOL')
# Out:
# Text(0.5, 1.0, 'Wt VS VOL')

# %%
plt.scatter(x=cars['WT'],y=cars['SP'])
plt.title('HP VS WT')
# Out:
# Text(0.5, 1.0, 'HP VS WT')

# %%
plt.scatter(x=cars['VOL'],y=cars['SP'])
plt.title('HP VS WT')
# Out:
# Text(0.5, 1.0, 'HP VS WT')

# %%
cars.corr()
# Out:
#            HP       MPG       VOL        SP        WT
# HP   1.000000 -0.725038  0.077459  0.973848  0.076513
# MPG -0.725038  1.000000 -0.529057 -0.687125 -0.526759
# VOL  0.077459 -0.529057  1.000000  0.102170  0.999203
# SP   0.973848 -0.687125  0.102170  1.000000  0.102439
# WT   0.076513 -0.526759  0.999203  0.102439  1.000000

# %%
cars.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()     
#Here We need to transform only the independent numeric cols
# Not Dependent cols here it is MPG
cars[['HP','WT','VOL','SP']] =sc.fit_transform(cars[['HP','WT','VOL','SP']])

# %%
cars.describe()
# Out:
#                  HP        MPG           VOL            SP            WT
# count  8.100000e+01  81.000000  8.100000e+01  8.100000e+01  8.100000e+01
# mean  -6.579099e-17  34.422076  1.021131e-16  1.345974e-15  1.091034e-15
# std    1.006231e+00   9.131445  1.006231e+00  1.006231e+00  1.006231e+00
# min   -1.206295e+00  12.101263 -2.200268e+00 -1.559242e+00 -2.242651e+00
# 25%   -5.896621e-01  27.856252 -4.406106e-01 -5.471360e-01 -3.788142e-01
# 50%   -3.077727e-01  35.152727  1.008224e-01 -2.363888e-01  4.323438e-02
# 75%    3.969507e-01  39.531633  6.422554e-01  3.451235e-01  6.687709e-01
# max    3.603442e+00  53.700681  2.762868e+00  3.409929e+00  2.764440e+00

# %%
np.round(cars.describe(),2)
# Out:
#           HP    MPG    VOL     SP     WT
# count  81.00  81.00  81.00  81.00  81.00
# mean   -0.00  34.42   0.00   0.00   0.00
# std     1.01   9.13   1.01   1.01   1.01
# min    -1.21  12.10  -2.20  -1.56  -2.24
# 25%    -0.59  27.86  -0.44  -0.55  -0.38
# 50%    -0.31  35.15   0.10  -0.24   0.04
# 75%     0.40  39.53   0.64   0.35   0.67
# max     3.60  53.70   2.76   3.41   2.76

# %% [markdown]
# # Simple Linear Regression

# %%
import statsmodels.formula.api as smf
ml_vol = smf.ols('MPG~VOL',data=cars).fit()
np.round(ml_vol.rsquared,2) # It will give the performance
# Out:
# np.float64(0.28)

# %%
ml_vol.params
# Out:
# Intercept    34.422076
# VOL          -4.801137
# dtype: float64

# %% [raw]
# Y= B1*X1 + B0 ---> Here b0 is intercept,B1 is vol intercept and x1 is vol and Y is MPG

# %%
# ml_wt = smf.ols('MPG~WT',data=cars).fit()#left--->Dependent variable and right -->dependent variable
# np.round(ml_wt.rsquared,2) # It will give the performance

# %%
# ml_wt.params

# %%
# ml_hp = smf.ols('MPG~HP',data=cars).fit() #Here 'MPG~HP' left--->Dependent variable and right -->dependent variable
# np.round(ml_hp.rsquared,2) # It will give the performance

# %%
# ml_hp.params

# %%
# ml_sp = smf.ols('MPG~SP',data=cars).fit()#left--->Dependent variable and right -->dependent variable
# np.round(ml_sp.rsquared,2) # It will give the performance

# %%
# ml_sp.params

# %% [markdown]
# # Preparing Model

# %%
model = smf.ols('MPG~WT+VOL+SP+HP',data=cars).fit()

# %%
np.round(model.rsquared,2)
# Out:
# np.float64(0.77)

# %%
model.params
# Out:
# Intercept    34.422076
# WT            2.982842
# VOL          -7.448031
# SP            5.575816
# HP          -11.660955
# dtype: float64

# %% [raw]
# # Y= B1*X1 + Here b1 is intercept and x1 is vol and y is MPy=β
# y=β0+β1X
# where:
#
# Y is the dependent variable
# X is the independent variable
# β0 is the intercept
# β1 is the slopeG

# %% [raw]
# y=β0+β1*X1+...βn*Xn
#
# where
# Y is the dependent variable
# X1, X2, …, Xn are the independent variables
# β0 is the intercept
# β1, β2, …, βn are the slopes

# %%
sns.regplot(x='MPG',y='VOL',data=cars)
# Out:
# <Axes: xlabel='MPG', ylabel='VOL'>

# %%
sns.regplot(x='MPG',y='WT',data=cars)
# Out:
# <Axes: xlabel='MPG', ylabel='WT'>

# %%
sns.regplot(x='MPG',y='HP',data=cars)
# Out:
# <Axes: xlabel='MPG', ylabel='HP'>

# %%
sns.regplot(x='MPG',y='SP',data=cars)
# Out:
# <Axes: xlabel='MPG', ylabel='SP'>

# %%
import statsmodels.api as sm
sm.qqplot(cars['HP'],line='s')
plt.show()
